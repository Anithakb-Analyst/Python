# %% [markdown]
# <a href="https://colab.research.google.com/github/Anithakb-Analyst/Python/blob/main/Anitha_K_B_DA_FINAL_PROJECT_STUDENT_PERFORMANCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Title :
#
# ###Student Performance Analysis in Secondary Education

# %% [markdown]
# # Domain:
# ### Education

# %% [markdown]
# # Objective:
#
# 1. To clean, preprocess, and analyze student performance datasets using Python (Pandas, NumPy).
#
# 2. To perform Exploratory Data Analysis (EDA) and identify relationships between academic scores and demographic or behavioral factors.
#
# 3. To visualize performance trends using Matplotlib and Seaborn.
#
# 4. To generate insights that help educators understand performance gaps and improve student outcomes.

# %% [markdown]
# # Outcome
#
# * Analyzed student performance data to identify factors affecting academic results.
#
# * Visualized academic trends and correlations using Python libraries.
#
# * Generated actionable insights through exploratory data analysis (EDA).

# %% [markdown]
# #Dataset Information
#
# **Source**: UCI ML Repository
#
# **Dataset Link**:    https://archive.ics.uci.edu/dataset/320/student+performance
#
# **Year / Timeline**:   Data collected during 2008
#
# **Dataset Description**:
#
# This data approach student achievement in secondary education of two Portuguese schools. The data attributes include student grades, demographic, social and school related features) and it was collected by using school reports and questionnaires. Two datasets are provided regarding the performance in two distinct subjects: Mathematics (mat) and Portuguese language (por). In [Cortez and Silva, 2008], the two datasets were modeled under binary/five-level classification and regression tasks. Important note: the target attribute G3 has a strong correlation with attributes G2 and G1. This occurs because G3 is the final year grade (issued at the 3rd period), while G1 and G2 correspond to the 1st and 2nd period grades. It is more difficult to predict G3 without G2 and G1, but such prediction is much more useful (see paper source for more details).

# %% [markdown]
# #Type of Analysis
#
# * **Descriptive Analysis**:
#
#     Analyzed distributions of grades (G1, G2, G3), age, absences, and study time
#     Summarized student demographics such as gender, school, and address type.
#
# * **Diagnostic Analysis**:
#
#     To identify the underlying factors and reasons behind variations in students’ final grades (G3) by analyzing academic, behavioral, and socio-economic attributes.
#
# * **Predictive Analysis**:
#
#     To predict students’ final academic performance (G3) based on academic history, behavioral patterns, and socio-demographic factors using Python.
#
# * **Prescriptive Analysis**:
#
#     To recommend data-driven actions and interventions that can improve student academic performance and reduce the risk of low final grades (G3).

# %% [markdown]
# # Stages for DA Project

# %% [markdown]
# #Stage 1:  Student Problem Definition and Expected Outcome:

# %% [markdown]
# 1. **Problem Definition**
#
#     Educational institutions need to understand the factors that influence student academic performance in order to identify at-risk students early and improve learning outcomes. Traditional methods often rely on manual observation, which may overlook hidden patterns in academic, demographic, and behavioral data.
#
#     This project aims to analyze student performance data to uncover relationships between academic results and factors such as study habits, attendance, family support, and lifestyle choices.

# %% [markdown]
# 2. **Expected Outcome**
#
#    * Identify key factors affecting students’ final grades (G3)
#    * Detect students at risk of poor academic performance
#    * Provide data-driven insights to support early academic intervention
#    * Build a foundation for predictive and prescriptive analysis.

# %% [markdown]
# 3. **Dataset Selection and Source Explanation**
#
#    ** Dataset Chosen**
#    - student-mat.csv (Mathematics course)
#     - student-por.csv (Portuguese language course)
#
#    ** Dataset Source**
#    *  UCI Machine Learning Repository
#     * Original data collected from two Portuguese secondary schools:
#     Gabriel Pereira (GP) and Mousinho da Silveira (MS)

# %% [markdown]
# 4. **Dataset Size and Features**
#
#     **Dataset Size:**
#     * Dataset :    	Rows	& Columns
#     * student-mat.csv:	395,	33
#    *  student-por.csv:	649,	33
#
#     **Feature Categories:**
#     * Demographic: age, sex, school, address
#     * Family & Socio-Economic: parental education, family size, family support
#     * Academic: study time, failures, absences, grades (G1, G2, G3)
#    *  Behavioral & Lifestyle: alcohol consumption, free time, going out.

# %% [markdown]
# 5. **Dataset Description**
#
#     **Rows**: Each row represents an individual student
#
#     **Columns:** 33 attributes including academic, demographic, and behavioral features
#
#    **Target Variable:**
#
#    Final Grade / Student Performance (e.g., G3) — represents the student’s overall academic outcome.

# %% [markdown]
# 6. **Initial Exploratory Data Analysis (EDA)**:
#
#     The initial EDA was conducted to understand the structure, quality, and basic statistical properties of the student performance dataset before deeper analysis.

# %% [markdown]
# **Dataset Loading Using UCI ML Repository**
#
# The dataset is loaded programmatically from the UCI Machine Learning Repository using the ucimlrepo library. This ensures data authenticity, reproducibility, and access to official metadata.

# %% [markdown]
# **Initial intalls & imports:**

# %%
pip install ucimlrepo

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
student_performance = fetch_ucirepo(id=320)

# data (as pandas dataframes)
X = student_performance.data.features
y = student_performance.data.targets

# metadata
print(student_performance.metadata)

# variable information
print(student_performance.variables)
# Out:
# {'uci_id': 320, 'name': 'Student Performance', 'repository_url': 'https://archive.ics.uci.edu/dataset/320/student+performance', 'data_url': 'https://archive.ics.uci.edu/static/public/320/data.csv', 'abstract': 'Predict student performance in secondary education (high school). ', 'area': 'Social Science', 'tasks': ['Classification', 'Regression'], 'characteristics': ['Multivariate'], 'num_instances': 649, 'num_features': 30, 'feature_types': ['Integer'], 'demographics': ['Sex', 'Age', 'Other', 'Education Level', 'Occupation'], 'target_col': ['G1', 'G2', 'G3'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2008, 'last_updated': 'Fri Jan 05 2024', 'dataset_doi': '10.24432/C5TG7T', 'creators': ['Paulo Cortez'], 'intro_paper': {'ID': 360, 'type': 'NATIVE', 'title': 'Using data mining to predict secondary school student performance', 'authors': 'P. Cortez, A. M. G. Silva', 'venue': 'Proceedings of 5th Annual Future Business Techno
# ...

# %%
## Combine feature variables and target variables into a single DataFrame
df = pd.concat([X, y], axis=1)

# %% [markdown]
# 1. Preview of the Dataset:

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %% [markdown]
# Observation:
#
# * Displays the first five rows of the dataset
# * Confirms the presence of both categorical and numerical features
# * Helps verify correct data loading

# %% [markdown]
# 2.Dataset Information:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %% [markdown]
# Observation:
#
# * The dataset contains 1,044 rows and 30 feature columns
# * Data types include int64, float64, and object
# * All columns have non-null values

# %% [markdown]
# 3. Statistical Summary:

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %% [markdown]
# Observation:
#
# * Numerical features such as age, studytime, failures, absences show reasonable ranges
# * Academic and behavioral variables display varying levels of dispersion
# * Helps detect potential outliers

# %% [markdown]
# 4. Dataset Shape:

# %%
df.shape
# Out:
# (649, 33)

# %% [markdown]
# Observation:
#
# * Rows : 649
# * Columns: 33

# %% [markdown]
# 5. Missing Values Check:

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# Observation:
#
# * No missing values detected across all features
# * Confirms dataset completeness

# %% [markdown]
# 6. Duplicate Records Check:

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# duplicates are dropped if any:
df.drop_duplicates()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
# Get the shape of the DataFrame before dropping duplicates
print(f"Shape before dropping duplicates: {df.shape}")

# Drop duplicate rows
df.drop_duplicates(inplace=True)

# Get the shape of the DataFrame after dropping duplicates
print(f"Shape after dropping duplicates: {df.shape}")
# Out:
# Shape before dropping duplicates: (649, 33)
# Shape after dropping duplicates: (649, 33)

# %% [markdown]
# Observation:
#
# * No duplicate rows found
# * Each record uniquely represents an individual student

# %% [markdown]
# **Key Takeaways from Initial EDA**
#
#
#   * Dataset is clean and ready for further analysis.
#   * Contains a mix of demographic, academic, and behavioral attributes.
#   * Suitable for diagnostic, predictive, and prescriptive analysis without extensive cleaning.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Stage 2 – Data Cleaning & Pre-processing

# %% [markdown]
# Objective:
#
# Ensure data quality, consistency, and reliability before analysis and modeling.

# %% [markdown]
# ##1. Handle Missing Values

# %%
# check for missing values:
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# Observation:
#
# There is no missing values

# %% [markdown]
# ##2. Handle duplicates:

# %%
# Check for duplicates:
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Observation:
#
# There is no duplicates in the dataset.

# %% [markdown]
# # 3. Data Type Conversion:

# %%
# Verify Data Types:
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# **Observation**:
# * Qualitative attributes and are correctly stored as object.
# * Quantitative and ordinal features are correctly stored as int64.
# * Target Variables are Grades.

# %% [markdown]
# ##Stage 2 Outcome :
#
# * Cleaned dataset with no missing values or duplicates
# * Correct data types assigned
# * Data prepared for EDA and machine learning

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #Stage 3 – Exploratory Data Analysis (EDA) & Visualizations
#
# ##Objective:
#  Identify academic, behavioral, and socio-economic factors influencing student performance and translate insights into actionable educational decisions.

# %% [markdown]
# ##1.UNIVARIATE ANALYSIS
# (Distribution of single variables (countplot, histogram, boxplot))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Countplots :

# %% [markdown]
# ## Gender Distribution of Students:

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='sex', data=df, width= 0.3, color='steelblue')
plt.title("Gender Distribution of Students")
plt.xlabel("Gender")
plt.ylabel("Number of Students")
plt.grid(axis="y", linestyle="--", alpha=0.4)
plt.show()

# %% [markdown]
# ### **Purpose:**
# * To understand gender representation in the dataset
# * To check for data imbalance that may affect analysis conclusions
#
# ### **Features Used**
#
# * sex – Gender (Male/Female)

# %% [markdown]
# ###***Business Interpretation***
#
# * *The dataset is gender-balanced, with the female students leading a bit, enabling fair gender-based performance analysis*.
# * *Observed performance differences later are behavioral or environmental, not due to data bias*.

# %% [markdown]
# ## Distribution of Study Time Levels:

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='studytime', data=df,width =0.5,color='lightgreen')
plt.title("Distribution of Study Time Levels")
plt.xlabel("Study Time Level")
plt.ylabel("Number of Students")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# ### **Purpose:**
# * To observe students’ weekly study habits
# * To identify whether most students fall into low, medium, or high study time categories
#
# ### **Features Used**
#
# * studytime – Weekly study time (ordinal scale

# %% [markdown]
# ###***Business Interpretation***
#
# * *Most students fall in moderate study time categories*.
# * *Very few students dedicate extremely high study hours*.
# * *Encouraging consistent study routines may yield better performance improvements.*

# %% [markdown]
# ## Histograms:

# %% [markdown]
# ##Age Distribution:

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['age'], bins=8, kde=True, color='brown')
plt.title("Age Distribution of Students")
plt.xlabel("Age")
plt.ylabel("Count")
plt.grid(axis="y", alpha=0.4)
plt.show()

# %% [markdown]
# ### **Purpose:**
# * To analyze the age range of students in secondary education
# * To identify dominant age groups and potential age-related performance risk
#
# ### **Features Used**
#
# * age – Student age

# %% [markdown]
# ###***Business Interpretation***
#
# * *Most students are between 15–18 years, indicating a standard secondary school population*.
# * *Age-related performance variations can be meaningfully analyzed*.

# %% [markdown]
# ##Distribution of Final Grades (G3)

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['G3'], bins=10, kde=True,color='pink')
plt.title("Distribution of Final Grades (G3)")
plt.xlabel("Final Grade")
plt.ylabel("Student Count")
plt.grid(axis="y", alpha=0.4)
plt.show()

# %% [markdown]
# ### **Purpose:**
# * To understand overall student performance distribution
# * To identify score concentration, skewness, and presence of low or high performers
# * To detect performance imbalance (e.g., majority average vs few high achievers)
#
# ### **Features Used**
#
# * G3 – Final grade

# %% [markdown]
# ###***Business Interpretation***
#
# * *Most students score in the mid-range, indicating average performance*.
# * *Very few students excel or fail drastically*.
# * *Educational strategies should focus on uplifting average performers*.

# %% [markdown]
# ## Boxplots:

# %% [markdown]
# ## Absences Distribution

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='absences',data=df, linewidth=1.5,color='brown')
plt.title("Absences Distribution")
plt.xlabel("Absences")
plt.ylabel("Student Count")
plt.show()

# %% [markdown]
# ### **Purpose:**
# * To detect extreme absenteeism and outliers
# * To assess variability in attendance behavior
#
# ### **Features Used**
#
# * absences – Number of school absences

# %% [markdown]
# ###***Business Interpretation***
#
# * *Majority of students have low absences*.
# * *Outliers with very high absences represent high-risk students*.
# * *Targeted attendance monitoring can improve academic outcomes*.*

# %% [markdown]
# ## Weekend Alcohol Consumption:

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df['Walc'])
plt.title("Weekend Alcohol Consumption Distribution")
plt.ylabel("Alcohol Consumption Level")
plt.show()

# %% [markdown]
# ### **Purpose:**
# * To analyze the distribution of students’ weekend alcohol consumption levels
# * To identify median consumption, variability, and outliers indicating high-risk drinking behavior
# * To detect extreme values that may negatively impact health, attendance, and academic performance
# * To support early identification of students who may require behavioral or academic intervention
#
# ### **Features Used**
#
# * Walc – Weekend alcohol consumption level (ordinal scale)

# %% [markdown]
# ###***Business Interpretation***
#
# * *Majority of students have low alcohol consumption*.
# * *A small group shows significantly higher consumption*.
# * *These students may require lifestyle counseling support*.

# %% [markdown]
# ## Key Univariate Insights Summary
#
# * Dataset is balanced and representative.
#
# * Most students are average performers.
#
# * Absenteeism and lifestyle extremes identify risk groups.
#
# * Behavioral and routine-based interventions can drive improvement.

# %% [markdown]
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# #1.BIVARIATE ANALYSIS
#
# (Relationship between two variables - scatterplot, barplot, correlation heatmap)

# %% [markdown]
# ## Scatterplot

# %% [markdown]
# ##  Absences vs Final Grade :

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='absences', y='G3', data=df)
plt.title("Absences vs Final Grade (G3)")
plt.xlabel("Number of Absences")
plt.ylabel("Final Grade")
plt.show()

# %% [markdown]
# ### **Purpose:**
# * To analyze how student attendance affects academic performance
# * To identify absenteeism as an early risk indicator for poor results
#
# ### **Features Used**
#
# * absences – Number of school absences
# * G3 – Final grade

# %% [markdown]
# ###***Business Interpretation***
#
# * *There is a clear negative relationship between absences and final grades*.
# * *Students with frequent absences consistently perform worse*.
# * *Attendance is a key early-warning indicator for academic failure*.

# %% [markdown]
# # Barplots:

# %% [markdown]
# ##Study Time vs Final Grade

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='studytime', y='G3', data=df,width = 0.5, color='olive' )
plt.title("Study Time vs Final Grade")
plt.xlabel("Study Time Level")
plt.ylabel("Average Final Grade")
plt.grid(axis="y", linestyle="--", alpha=0.4)
plt.show()

# %% [markdown]
# ### **Purpose:**
# * To understand the impact of study habits on student performance
# * To assess whether increased study time leads to better grades
#
# ### **Features Used**
#
# * studytime – Weekly study time
# * G3 – Final grade

# %% [markdown]
# ### ***Business Interpretation***
#
# * *Average grades improve with increased study time*.
# * *Improvement plateaus at higher levels, suggesting diminishing returns*.
# * *Emphasizes the importance of effective study strategies, not just longer hours*.

# %% [markdown]
# ## Weekend Alcohol Consumption vs Final Grade

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='Walc', y='G3', data=df, width = 0.5,color='cyan')
plt.title("Weekend Alcohol Consumption vs Final Grade")
plt.xlabel("Weekend Alcohol Consumption Level")
plt.ylabel("Average Final Grade")
plt.grid(axis="y", linestyle="--", alpha=0.4)
plt.show()

# %% [markdown]
# ### **Purpose:**
# * To evaluate the effect of lifestyle behavior on academic outcomes
# * To identify risk associated with high alcohol consumption
#
# ### **Features Used**
#
# * Walc – Weekend alcohol consumption
# * G3 – Final grade

# %% [markdown]
# ###***Business Interpretation***
#
# * *Higher alcohol consumption is linked to lower academic performance*.
# * *Lifestyle behavior has a direct academic impact*.
# * *Supports need for awareness and wellness programs*.

# %% [markdown]
# ## Gender vs Final Grade

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='sex', y='G3', data=df,width = 0.3)
plt.title("Gender vs Final Grade")
plt.xlabel("Gender")
plt.ylabel("Average Final Grade")
plt.grid(axis="y", linestyle="--", alpha=0.4)
plt.show()

# %% [markdown]
# ### **Purpose:**
# * To check if academic performance differs by gender
# * To ensure fairness and absence of gender bias in performance trends
#
# ### **Features Used**
#
# * sex – Gender
# * G3 – Final grade

# %% [markdown]
# ###***Business Interpretation***
#
# * *Average performance across genders is comparable*.
# * *Academic outcomes are more influenced by behavior and support than gender*.

# %% [markdown]
# ## Correlation Heatmap

# %% [markdown]
# ## Correlation of Numerical Features

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='PuBu', linewidths=0.5,linecolor='black',fmt=".2f")
plt.title("Correlation Heatmap of Numerical Variables")
plt.show()

# %% [markdown]
# ### **Purpose:**
# * To measure the strength and direction of relationships between numerical features
# * To identify strong predictors for modeling
#
# ### **Features Used**
#
# * Numerical variables such as:
#
#   * G1, G2, G3
#   * absences, studytime, failures
#   * Dalc, Walc, age, health

# %% [markdown]
# ### ***Business Interpretation***
#
# * *Strong correlation between G1, G2, and G3.*
# * *Absences and alcohol consumption negatively impact grades*.
# * *These features are strong candidates for predictive modeling*.

# %% [markdown]
# # Key Bivariate Insights Summary
#
# * Attendance is one of the strongest predictors of performance.
#
# * Study time positively impacts grades but has diminishing returns.
#
# * Lifestyle habits significantly affect academic outcomes.
#
# * Early academic scores predict final success.

# %% [markdown]
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# # 3. MULTIVARIATE ANALYSIS:
#
# (Relation among 3+ variables - pairplot, grouped analysis, pivot tables, advanced plots)

# %% [markdown]
# ## Pairplot

# %% [markdown]
# ## Academic Performance & Attendance

# %%
sns.pairplot(
    df[['G1', 'G2', 'G3', 'absences']],
    diag_kind="kde",
)
plt.suptitle("Academic Performance & Attendance", y=1.02)
plt.show()

# %% [markdown]
# ###  **Purpose:**
#
# * Track academic progression across periods
# * Identify early warning signs of poor performance
#
# ### **Features Used**
#
# * G1 – First period grade
# * G2 – Second period grade
# * G3 – Final grade
# * absences – Number of school absences

# %% [markdown]
# ### ***Business Interpretation***
#
# * *Strong linear progression from G1 → G2 → G3*.
# * *Students who perform poorly early rarely recover without intervention*.
# * *Absences negatively affect all grade stages*.
# * *Supports early academic monitoring systems*.

# %% [markdown]
# ## Grouped Barplot

# %% [markdown]
# ## Study Time vs Final Grade by Gender

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='studytime', y='G3', hue='sex', data=df)
plt.title("Study Time vs Final Grade by Gender")
plt.xlabel("Study Time Level")
plt.ylabel("Average Final Grade")
plt.show()

# %% [markdown]
# ### **Purpose**
# * Measure effectiveness of study time across genders
# * Check if gender-specific interventions are required
#
# ### **Features Used**
#
# * Studytime – Weekly study time
# * G3 – Final grade
# * sex – Gender

# %% [markdown]
# ### ***Business Interpretation***
#
# * *Increased study time improves performance for both genders*.
# * *Gender gap narrows as study time increases*.
# * *Academic improvement strategies can be gender-neutral*.*italicised text*

# %% [markdown]
# ##School Support & Past Failures vs Final Grade

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='failures', y='G3', hue='schoolsup', data=df)
plt.title("Past Failures & School Support vs Final Grade")
plt.xlabel("Number of Past Failures")
plt.ylabel("Average Final Grade")
plt.show()

# %% [markdown]
# ### **Purpose**
#
# * Evaluate effectiveness of remedial education programs
# * Measure recovery potential after academic setbacks
#
# ### **Features Used**
#
# * failures – Number of past class failures
# * schoolsup – School support (yes/no)
# * G3 – Final grade

# %% [markdown]
# ###***Business Interpretation***
#
# * *Students with past failures perform better when school support is present*.
# * *Academic support programs help mitigate prior academic setbacks*.
# * *Justifies investment in remedial education*.

# %% [markdown]
# ##Pivot Table

# %% [markdown]
# ## Family Support & Internet Access vs Final Grade :

# %%
pd.pivot_table(
    df,
    values='G3',
    index='famsup',
    columns='internet',
    aggfunc='mean'
)
# Out:
# internet         no        yes
# famsup
# no        10.367647  12.147541
# yes       11.566265  12.187302

# %% [markdown]
# ### **Purpose:**
# * Evaluate home environment impact on academic success
# * Support digital inclusion initiatives
#
# ### **Features Used**
#
# * famsup – Family educational support
# * internet – Internet access at home
# * G3 – Final grade

# %% [markdown]
# ### ***Business Interpretation***
#
# * *Students with family support and internet access perform best*.
# * *Lack of either factor reduces performance*.
# * *Highlights importance of digital inclusion and parental engagement*.

# %% [markdown]
# ## Grouped Boxplot

# %% [markdown]
# ## Alcohol Consumption & Study Time vs Final Grade

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='Walc', y='G3', hue='studytime', data=df)
plt.title("Weekend Alcohol Consumption & Study Time vs Final Grade")
plt.xlabel("Weekend Alcohol Consumption Level")
plt.ylabel("Final Grade")
plt.show()

# %% [markdown]
# ### **Purpose**
#
# * Understand lifestyle–academics interaction
# * Identify students at risk despite good study habits
#
# ### **Features Used**
#
# * Walc – Weekend alcohol consumption
# * studytime – Study time
# * G3 – Final grade

# %% [markdown]
# ### ***Business Interpretation***
#
# * *High alcohol consumption reduces grades even among students who study more*.
# * *Healthy lifestyle amplifies benefits of academic effort*.
# * *Wellness programs are essential alongside academic initiatives*.

# %% [markdown]
# ## Grouped Scatterplot

# %% [markdown]
# ## Travel Time, Absences & Final Grade

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(
    x='traveltime',
    y='G3',
    size='absences',
    hue='absences',
    data=df
)
plt.title("Travel Time, Absences & Final Grade")
plt.xlabel("Travel Time")
plt.ylabel("Final Grade")
plt.show()

# %% [markdown]
# ### **Purpose**
#
# * Assess impact of commute on attendance and performance
# * Support transport and accessibility policy decisions
#
# ### **Features Used**
#
# * traveltime – Travel time to school
# * absences – Number of absences
# * G3 – Final grade

# %% [markdown]
# ###***Business Interpretation***
#
# * *Longer travel time increases absences and reduces performance.*
# * *Transportation and housing proximity impact academic success*.
# * *Supports policies for school accessibility and transport support*.

# %% [markdown]
# # Key Multivariate Insights Summary
#
# * Early academic performance strongly predicts final outcomes.
#
# * Study habits and lifestyle choices jointly influence success.
#
# * Family support and digital access significantly enhance results.
#
# * Institutional support reduces the impact of past failures.

# %% [markdown]
# # Overall Business Story
#
# * Student success is driven by a combination of academic effort, lifestyle behavior, and support systems.
#
# * Early detection and targeted interventions yield the highest impact.
#
# * Data supports holistic education policies rather than isolated actions.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #Stage 4 – Documentation, Insights and Presentation

# %% [markdown]
# ##Converting the dataset file as csv file:

# %%
df.to_csv('my_data.csv', index=False)

# %%
import pandas as pd

# Read the CSV file back into a DataFrame
my_data_df = pd.read_csv('my_data.csv')

# Display the first 5 rows of the DataFrame
display(my_data_df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %% [markdown]
# ##Documentation link:
# #https://drive.google.com/file/d/1Hlyxx618o1UtQp0t-06OvMgx3WsrIStV/view?usp=drive_link

# %% [markdown]
# ##Conclusion
# From the analysis, we identified meaningful relationships and patterns in the dataset. The visualizations and insights highlight the main factors influencing the outcomes and provide a strong foundation for business decisions.
